# %% [markdown]
# Q1) What is a parameter?
#
# Ans:- A parameter is a configuration variable that is internal to the model and estimated from the data, such as the coefficients in linear regression.
#
# Q2) What is correlation?
#
# Ans:- Correlation is a statistical measure that expresses the extent to which two variables are linearly related.
#
# Q3) What does negative correlation mean?
#
# Ans:- Negative correlation means that as one variable increases, the other decreases. They move in opposite directions.
#
# Q4) Define Machine Learning. What are the main components in Machine Learning?
#
# Ans:- Machine Learning is a subset of AI that enables systems to learn from data and improve performance over time without being explicitly programmed.
# Main components:
#
# Dataset
#
# Model
#
# Loss function
#
# Optimizer
#
# Evaluation metrics
#
# Q5) How does loss value help in determining whether the model is good or not?
#
# Ans:- Loss value quantifies the error between predicted and actual outputs. A lower loss indicates better model performance.
#
# Q6) What are continuous and categorical variables?
#
# Ans:-
#
# Continuous variables: Numeric values that can take an infinite range (e.g., height, weight).
#
# Categorical variables: Represent categories or labels (e.g., gender, color).
#
# Q7) How do we handle categorical variables in Machine Learning? What are the common techniques?
#
# Ans:-
# Common techniques:
#
# One-Hot Encoding
#
# Label Encoding
#
# Ordinal Encoding
#
# Binary Encoding
#
# Q8) What do you mean by training and testing a dataset?
#
# Ans:-
#
# Training dataset: Used to train the model.
#
# Testing dataset: Used to evaluate the model’s performance on unseen data.
#
# Q9) What is sklearn.preprocessing?
#
# Ans:- sklearn.preprocessing is a module in Scikit-learn that contains functions to transform or scale data, like encoding or normalization.
#
# Q10) What is a Test set?
#
# Ans:- A test set is a portion of the dataset used to evaluate the final model performance after training.
#
# Q11) How do we split data for model fitting (training and testing) in Python?
#
# Ans:-
# Using train_test_split() from sklearn.model_selection:
#
# python
# Copy
# Edit
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# Q12) How do you approach a Machine Learning problem?
#
# Ans:-
#
# Understand the problem
#
# Gather and clean data
#
# Perform EDA
#
# Feature engineering
#
# Choose model
#
# Train and validate model
#
# Evaluate performance
#
# Tune and deploy
#
# Q13) Why do we have to perform EDA before fitting a model to the data?
#
# Ans:- EDA helps understand the dataset, detect patterns, identify outliers, handle missing data, and choose appropriate models and features.
#
# Q14) What is correlation?
#
# Ans:- Correlation measures the linear relationship between two variables, ranging from -1 to 1.
#
# Q15) What does negative correlation mean?
#
# Ans:- It means that an increase in one variable results in a decrease in another.
#
# Q16) How can you find correlation between variables in Python?
#
# Ans:-
# Using Pandas:
#
# python
# Copy
# Edit
# df.corr()
# Or visualize using:
#
# python
# Copy
# Edit
# import seaborn as sns
# sns.heatmap(df.corr(), annot=True)
# Q17) What is causation? Explain difference between correlation and causation with an example.
#
# Ans:-
#
# Causation: One variable directly affects another.
#
# Correlation: Variables move together but may not be causally linked.
# Example: Ice cream sales and drowning incidents are correlated but not causal. The actual cause is temperature (a confounding variable).
#
# Q18) What is an Optimizer? What are different types of optimizers? Explain each with an example.
#
# Ans:- An optimizer adjusts model parameters to minimize loss.
# Common types:
#
# SGD: Updates weights using gradients on each batch.
#
# Adam: Combines momentum and RMSprop for faster convergence.
#
# RMSprop: Uses moving average of squared gradients.
# Example:
#
# python
# Copy
# Edit
# from tensorflow.keras.optimizers import Adam
# model.compile(optimizer=Adam(), loss='mse')
# Q19) What is sklearn.linear_model?
#
# Ans:- sklearn.linear_model is a Scikit-learn module that provides linear models like LinearRegression, LogisticRegression.
#
# Q20) What does model.fit() do? What arguments must be given?
#
# Ans:- Trains the model on given data.
# Arguments: X_train (features), y_train (target)
#
# python
# Copy
# Edit
# model.fit(X_train, y_train)
# Q21) What does model.predict() do? What arguments must be given?
#
# Ans:- Predicts target values for given input features.
# Arguments: Input features X_test
#
# python
# Copy
# Edit
# model.predict(X_test)
# Q22) What are continuous and categorical variables?
#
# Ans:-
#
# Continuous: Real numbers (e.g., salary, age)
#
# Categorical: Discrete categories (e.g., country, color)
#
# Q23) What is feature scaling? How does it help in Machine Learning?
#
# Ans:- Feature scaling standardizes input variables to a common scale. It helps models converge faster and prevents one feature from dominating others.
#
# Q24) How do we perform scaling in Python?
#
# Ans:-
# Using StandardScaler:
#
# python
# Copy
# Edit
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)
# Q25) What is sklearn.preprocessing?
#
# Ans:- A module for transforming data, such as scaling, encoding, and normalization.
#
# Q26) How do we split data for model fitting (training and testing) in Python?
#
# Ans:-
# Using train_test_split:
#
# python
# Copy
# Edit
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# Q27) Explain data encoding?
#
# Ans:- Data encoding is the process of converting categorical variables into numerical form so that they can be used in ML models. Techniques include One-Hot Encoding, Label Encoding, and Ordinal Encoding.
